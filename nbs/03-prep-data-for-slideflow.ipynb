# %% [markdown]
# # Choose data for slideflow

# %%
import os
from pathlib import Path
import pandas as pd
import numpy as np
from glob import glob

dirpath = Path.cwd()
print(dirpath)
# Out:
# /Users/apartin/Box/work/jdacs/pdx-histo/nbs

# %% [markdown]
# ## Load data

# %%
datapath = dirpath/'../data'
metapath = datapath/'meta'
df = pd.read_csv(metapath/'meta_merged.csv')
print(df.shape)
display(df[:2])
# Out:
# (458, 15)
#           model  patient_id specimen_id sample_id  image_id  Notes  \
# 0  114434~197-R      114434       197-R    A35YC3     27166    NaN
# 1  114434~197-R      114434       197-R    A36YC9     25127    NaN
#
#   tumor_site_from_data_src         tumor_type_from_data_src  \
# 0          Musculoskeletal  Non-Rhabdo. soft tissue sarcoma
# 1          Musculoskeletal  Non-Rhabdo. soft tissue sarcoma
#
#   simplified_tumor_site simplified_tumor_type stage_or_grade     MPP  width  \
# 0       musculoskeletal  sarcoma/mesothelioma        grade 3  0.5027  23904
# 1       musculoskeletal  sarcoma/mesothelioma        grade 3  0.5027  19920
#
#    height  power
# 0   17995     20
# 1   17339     20

# %%
c = 'tumor_site_from_data_src'
print(df[c].nunique())
tt = df.groupby([c]).agg({'model': 'nunique',
                          'patient_id': 'nunique',
                          'specimen_id': 'nunique',
                          'image_id': 'nunique'}).reset_index()
display(tt)
# Out:
# 8
#        tumor_site_from_data_src  model  patient_id  specimen_id  image_id
# 0    Digestive/Gastrointestinal     23          17           23       138
# 1  Endocrine and Neuroendocrine      3           3            3        17
# 2                 Genitourinary      9           8            9        53
# 3                   Gynecologic      6           6            6        38
# 4                 Head and Neck      7           7            7        46
# 5               Musculoskeletal     14          14           13        85
# 6          Respiratory/Thoracic      7           7            6        42
# 7                          Skin      7           7            7        39

# %%
c = 'tumor_type_from_data_src'
print(df[c].nunique())
tt = df.groupby(['tumor_type_from_data_src']).agg({'model': 'nunique',
                                                   'patient_id': 'nunique', 
                                                   'specimen_id': 'nunique',
                                                   'image_id': 'nunique'}).reset_index()
display(tt)
# Out:
# 34
#              tumor_type_from_data_src  model  patient_id  specimen_id  \
# 0             Adenocarcinoma - cervix      1           1            1
# 1              Adenocarcinoma - colon      9           6            9
# 2           Adenocarcinoma - pancreas     10           7           10
# 3      Adenocarcinoma - small intest.      1           1            1
# 4        Carcinosarcoma of the uterus      2           2            2
# 5                      Chondrosarcoma      1           1            1
# 6              Colorectal cancer, NOS      1           1            1
# 7       Ewing sarcoma/Peripheral PNET      1           1            1
# 8   Female reprod. system cancer, NOS      1           1            1
# 9                 Gastric cancer, NOS      1           1            1
# 10     Gastrointestinal stromal tumor      1           1            1
# 11      H & N squamous cell car., NOS      3           3            3
# 12    Hurthle cell neoplasm (thyroid)      1           1            1
# 13       Leiomyosarcoma - not uterine      1           1            1
# 14            Leiomyosarcoma - uterus      1           1            1
# 15   Lip/oral cavity squam. cell car.      2           2            2
# 16                Lung adenocarcinoma      1           1            1
# 17   Malig. periph. nerve sheath tum.      2           2            2
# 18                           Melanoma      5           5            5
# 19                  Merkel cell tumor      2           2            2
# 20         Neuroendocrine cancer, NOS      1           1            1
# 21    Non-Rhabdo. soft tissue sarcoma      1           1            1
# 22                       Osteosarcoma      3           3            3
# 23          Ovarian epithelial cancer      1           1            1
# 24          Renal cell carcinoma, NOS      3           2            3
# 25              Rhabdomyosarcoma, NOS      1           1            1
# 26              Salivary gland cancer      2           2            2
# 27   Small cell car. (extrapulmonary)      1           1            1
# 28             Small cell lung cancer      1           1            1
# 29       Squamous cell lung carcinoma      5           5            4
# 30                   Synovial sarcoma      3           3            3
# 31    Transitional cell car. - uroth.      2           2            2
# 32     Urothelial/bladder cancer, NOS      4           4            4
# 33                Vaginal cancer, NOS      1           1            1
#
#     image_id
# 0          6
# 1         53
# 2         64
# 3          7
# 4         12
# 5          7
# 6          4
# 7          6
# 8          7
# 9          6
# 10         4
# 11        17
# 12         6
# 13         5
# 14         9
# 15        14
# 16         7
# 17         7
# 18        29
# 19        10
# 20         6
# 21         6
# 22        20
# 23         7
# 24        16
# 25         5
# 26        15
# 27         5
# 28         4
# 29        31
# 30        20
# 31        12
# 32        25
# 33         6

# %% [markdown]
# ## Choose the tissue/cancer types

# %%
# types = ['Melanoma', 'Salivary gland cancer']
types = ['Melanoma', 'Salivary gland cancer']
aa = df[ df['tumor_type_from_data_src'].isin(types) ]
display(aa)
# Out:
#             model  patient_id specimen_id        sample_id  image_id  Notes  \
# 6    114551~080-T      114551       080-T         M667M226     16056    NaN
# 7    114551~080-T      114551       080-T      M667M226C21     16127    NaN
# 8    114551~080-T      114551       080-T      M667M226C29     16142    NaN
# 9    114551~080-T      114551       080-T      M667M227C30     16131    NaN
# 10   114551~080-T      114551       080-T         M667M228     16058    NaN
# 11   114551~080-T      114551       080-T      M667M228C43     16149    NaN
# 12   114551~080-T      114551       080-T      M667M229C04     16066    NaN
# 13   114551~080-T      114551       080-T      M667M229C06     16152    NaN
# 14   114551~080-T      114551       080-T             M676     16065    NaN
# 39   156681~154-R      156681       154-R              A26      7593    NaN
# 40   156681~154-R      156681       154-R     A26A88AJ3AW1     11827    NaN
# 41   156681~154-R      156681       154-R  A26A88AJ4I88_RG     11520    NaN
# 42   156681~154-R      156681       154-R     A26A89AJ5AW4      9970    NaN
# 43   156681~154-R      156681       154-R     A26A89AJ6AU1     11107    NaN
# 75   174941~126-T      174941       126-T              DA3     13555    NaN
# 76   174941~126-T      174941       126-T        DA3DW5YB6     19422    NaN
# 77   174941~126-T      174941       126-T     DA3DW5YB6Z33     21570    NaN
# 78   174941~126-T      174941       126-T           DA3DW6     14575    NaN
# 79   174941~126-T      174941       126-T           DA4DZ5     14578    NaN
# 80   174941~126-T      174941       126-T        DA4DZ7WS8     19096    NaN
# 203  345371~062-R      345371       062-R              P24     13325    NaN
# 204  345371~062-R      345371       062-R           P25PJ8     13582    NaN
# 205  345371~062-R      345371       062-R              P26     11906    NaN
# 206  345371~062-R      345371       062-R           P26PK3     14252    NaN
# 207  345371~062-R      345371       062-R           P26PK6     13816    NaN
# 208  345371~062-R      345371       062-R           P27PQ6     14250    NaN
# 310  563396~261-R      563396       261-R           KN9L92     10636    NaN
# 311  563396~261-R      563396       261-R   KN9L97_RG-M706     11792    NaN
# 312  563396~261-R      563396       261-R   KN9L97_RG-M710     11549    NaN
# 313  563396~261-R      563396       261-R              KP0      9712    NaN
# 314  563396~261-R      563396       261-R           KP1LD4     10524    NaN
# 315  563396~261-R      563396       261-R           KP1LD5     10813    NaN
# 390  695669~166-R      695669       166-R              WR6     15903    NaN
# 391  695669~166-R      695669       166-R           WR6VC5     19398    NaN
# 392  695669~166-R      695669       166-R           WR6VC6     20232    NaN
# 393  695669~166-R      695669       166-R              WR7     14639    NaN
# 394  695669~166-R      695669       166-R           WR7V96     19020    NaN
# 395  695669~166-R      695669       166-R           WR8VB8     19166    NaN
# 452  773659~155-R      773659       155-R              NQ6     13882    NaN
# 453  773659~155-R      773659       155-R           NQ6E39     14834    NaN
# 454  773659~155-R      773659       155-R              NQ8     14267    NaN
# 455  773659~155-R      773659       155-R           NQ8K16     14990    NaN
# 456  773659~155-R      773659       155-R           NQ8K17     14991    NaN
# 457  773659~155-R      773659       155-R       NQ8K19M745     21836    NaN
#
#     tumor_site_from_data_src tumor_type_from_data_src simplified_tumor_site  \
# 6              Head and Neck    Salivary gland cancer           head & neck
# 7              Head and Neck    Salivary gland cancer           head & neck
# 8              Head and Neck    Salivary gland cancer           head & neck
# 9              Head and Neck    Salivary gland cancer           head & neck
# 10             Head and Neck    Salivary gland cancer           head & neck
# 11             Head and Neck    Salivary gland cancer           head & neck
# 12             Head and Neck    Salivary gland cancer           head & neck
# 13             Head and Neck    Salivary gland cancer           head & neck
# 14             Head and Neck    Salivary gland cancer           head & neck
# 39                      Skin                 Melanoma                  skin
# 40                      Skin                 Melanoma                  skin
# 41                      Skin                 Melanoma                  skin
# 42                      Skin                 Melanoma                  skin
# 43                      Skin                 Melanoma                  skin
# 75                      Skin                 Melanoma                  skin
# 76                      Skin                 Melanoma                  skin
# 77                      Skin                 Melanoma                  skin
# 78                      Skin                 Melanoma                  skin
# 79                      Skin                 Melanoma                  skin
# 80                      Skin                 Melanoma                  skin
# 203            Head and Neck    Salivary gland cancer           head & neck
# 204            Head and Neck    Salivary gland cancer           head & neck
# 205            Head and Neck    Salivary gland cancer           head & neck
# 206            Head and Neck    Salivary gland cancer           head & neck
# 207            Head and Neck    Salivary gland cancer           head & neck
# 208            Head and Neck    Salivary gland cancer           head & neck
# 310                     Skin                 Melanoma                  skin
# 311                     Skin                 Melanoma                  skin
# 312                     Skin                 Melanoma                  skin
# 313                     Skin                 Melanoma                  skin
# 314                     Skin                 Melanoma                  skin
# 315                     Skin                 Melanoma                  skin
# 390                     Skin                 Melanoma                  skin
# 391                     Skin                 Melanoma                  skin
# 392                     Skin                 Melanoma                  skin
# 393                     Skin                 Melanoma                  skin
# 394                     Skin                 Melanoma                  skin
# 395                     Skin                 Melanoma                  skin
# 452                     Skin                 Melanoma                  skin
# 453                     Skin                 Melanoma                  skin
# 454                     Skin                 Melanoma                  skin
# 455                     Skin                 Melanoma                  skin
# 456                     Skin                 Melanoma                  skin
# 457                     Skin                 Melanoma                  skin
#
#     simplified_tumor_type stage_or_grade     MPP  width  power  height
# 6             head & neck        grade 2  0.5027  21912     20   18813
# 7             head & neck        grade 2  0.5027  15936     20   14392
# 8             head & neck        grade 2  0.5027  19920     20   17585
# 9             head & neck        grade 2  0.5027  17928     20   17666
# 10            head & neck        grade 2  0.5027  27888     20   17913
# 11            head & neck        grade 2  0.5027  15936     20   18976
# 12            head & neck        grade 2  0.5027  19920     20   15374
# 13            head & neck        grade 2  0.5027  17928     20   17257
# 14            head & neck        grade 2  0.5027  19920     20   19877
# 39               melanoma            NaN  0.5006  15935     20   16929
# 40               melanoma            NaN  0.5006  29879     20   27104
# 41               melanoma            NaN  0.5006  21911     20   23152
# 42               melanoma            NaN  0.5006  15935     20   15623
# 43               melanoma            NaN  0.5006  19919     20   24043
# 75               melanoma            NaN  0.5027  11952     20    9807
# 76               melanoma            NaN  0.5027  11952     20   12345
# 77               melanoma            NaN  0.5027  21912     20   20942
# 78               melanoma            NaN  0.5027  19920     20   16111
# 79               melanoma            NaN  0.5027  19920     20   16602
# 80               melanoma            NaN  0.5027  13944     20   13409
# 203           head & neck        grade 3  0.5027  15936     20   13819
# 204           head & neck        grade 3  0.5027  15936     20   13573
# 205           head & neck        grade 3  0.5006  17927     20   14977
# 206           head & neck        grade 3  0.5027  19920     20   16193
# 207           head & neck        grade 3  0.5027  13944     20   19794
# 208           head & neck        grade 3  0.5027  15936     20   15210
# 310              melanoma            NaN  0.5006  21911     20   22097
# 311              melanoma            NaN  0.5006  21911     20   23968
# 312              melanoma            NaN  0.5006  29879     20   20895
# 313              melanoma            NaN  0.5006  21911     20   18910
# 314              melanoma            NaN  0.5006  23903     20   19571
# 315              melanoma            NaN  0.5006  27887     20   23583
# 390              melanoma            NaN  0.5027  13944     20   14883
# 391              melanoma            NaN  0.5027  15936     20   17339
# 392              melanoma            NaN  0.5027  15936     20   14637
# 393              melanoma            NaN  0.5027  25896     20   16767
# 394              melanoma            NaN  0.5027  15936     20   19385
# 395              melanoma            NaN  0.5027  17928     20   11117
# 452              melanoma            NaN  0.5027  27888     20   17258
# 453              melanoma            NaN  0.5027  15936     20   12673
# 454              melanoma            NaN  0.5027  13944     20   13163
# 455              melanoma            NaN  0.5027  21912     20   17012
# 456              melanoma            NaN  0.5027  23904     20   17995
# 457              melanoma            NaN  0.5027  21912     20   21678

# %%
n = 5
bb1 = aa[ aa['tumor_type_from_data_src'] == types[0] ][:n]
bb2 = aa[ aa['tumor_type_from_data_src'] == types[1] ][:n]
df_meta = pd.concat([bb1, bb2]).reset_index(drop=True)
df_meta
# Out:
#           model  patient_id specimen_id        sample_id  image_id  Notes  \
# 0  156681~154-R      156681       154-R              A26      7593    NaN
# 1  156681~154-R      156681       154-R     A26A88AJ3AW1     11827    NaN
# 2  156681~154-R      156681       154-R  A26A88AJ4I88_RG     11520    NaN
# 3  156681~154-R      156681       154-R     A26A89AJ5AW4      9970    NaN
# 4  156681~154-R      156681       154-R     A26A89AJ6AU1     11107    NaN
# 5  114551~080-T      114551       080-T         M667M226     16056    NaN
# 6  114551~080-T      114551       080-T      M667M226C21     16127    NaN
# 7  114551~080-T      114551       080-T      M667M226C29     16142    NaN
# 8  114551~080-T      114551       080-T      M667M227C30     16131    NaN
# 9  114551~080-T      114551       080-T         M667M228     16058    NaN
#
#   tumor_site_from_data_src tumor_type_from_data_src simplified_tumor_site  \
# 0                     Skin                 Melanoma                  skin
# 1                     Skin                 Melanoma                  skin
# 2                     Skin                 Melanoma                  skin
# 3                     Skin                 Melanoma                  skin
# 4                     Skin                 Melanoma                  skin
# 5            Head and Neck    Salivary gland cancer           head & neck
# 6            Head and Neck    Salivary gland cancer           head & neck
# 7            Head and Neck    Salivary gland cancer           head & neck
# 8            Head and Neck    Salivary gland cancer           head & neck
# 9            Head and Neck    Salivary gland cancer           head & neck
#
#   simplified_tumor_type stage_or_grade     MPP  width  power  height
# 0              melanoma            NaN  0.5006  15935     20   16929
# 1              melanoma            NaN  0.5006  29879     20   27104
# 2              melanoma            NaN  0.5006  21911     20   23152
# 3              melanoma            NaN  0.5006  15935     20   15623
# 4              melanoma            NaN  0.5006  19919     20   24043
# 5           head & neck        grade 2  0.5027  21912     20   18813
# 6           head & neck        grade 2  0.5027  15936     20   14392
# 7           head & neck        grade 2  0.5027  19920     20   17585
# 8           head & neck        grade 2  0.5027  17928     20   17666
# 9           head & neck        grade 2  0.5027  27888     20   17913

# %%
sorted(df_meta['image_id'])
# Out:
# [7593, 9970, 11107, 11520, 11827, 16056, 16058, 16127, 16131, 16142]

# %% [markdown]
# # Copy image metadata to pdx-proj for SlideFlow

# %%
import shutil

# %%
# src_img_path = datapath/'svs_images'
src_img_path = datapath/'doe-globus-pdx-data'
dst_img_path = Path('/Users/apartin/work/jdacs/slideflow-proj/pdx-proj/slides')

# %%
for fname in df_meta['image_id'].values:
    _ = shutil.copyfile(str(src_img_path/f'{fname}.svs'), str(dst_img_path/f'{fname}.svs'))

# %% [markdown]
# # Create files for slideflow

# %%
df_meta.sort_values('image_id')
# Out:
#           model  patient_id specimen_id        sample_id  image_id  \
# 0  156681~154-R      156681       154-R              A26      7593
# 3  156681~154-R      156681       154-R     A26A89AJ5AW4      9970
# 4  156681~154-R      156681       154-R     A26A89AJ6AU1     11107
# 2  156681~154-R      156681       154-R  A26A88AJ4I88_RG     11520
# 1  156681~154-R      156681       154-R     A26A88AJ3AW1     11827
# 5  114551~080-T      114551       080-T         M667M226     16056
# 9  114551~080-T      114551       080-T         M667M228     16058
# 6  114551~080-T      114551       080-T      M667M226C21     16127
# 8  114551~080-T      114551       080-T      M667M227C30     16131
# 7  114551~080-T      114551       080-T      M667M226C29     16142
#
#   tumor_site_from_data_src tumor_type_from_data_src simplified_tumor_site  \
# 0                     Skin                 Melanoma                  skin
# 3                     Skin                 Melanoma                  skin
# 4                     Skin                 Melanoma                  skin
# 2                     Skin                 Melanoma                  skin
# 1                     Skin                 Melanoma                  skin
# 5            Head and Neck    Salivary gland cancer           head & neck
# 9            Head and Neck    Salivary gland cancer           head & neck
# 6            Head and Neck    Salivary gland cancer           head & neck
# 8            Head and Neck    Salivary gland cancer           head & neck
# 7            Head and Neck    Salivary gland cancer           head & neck
#
#   simplified_tumor_type stage_or_grade  power  height  width     MPP
# 0              melanoma            NaN     20   16929  15935  0.5006
# 3              melanoma            NaN     20   15623  15935  0.5006
# 4              melanoma            NaN     20   24043  19919  0.5006
# 2              melanoma            NaN     20   23152  21911  0.5006
# 1              melanoma            NaN     20   27104  29879  0.5006
# 5           head & neck        grade 2     20   18813  21912  0.5027
# 9           head & neck        grade 2     20   17913  27888  0.5027
# 6           head & neck        grade 2     20   14392  15936  0.5027
# 8           head & neck        grade 2     20   17666  17928  0.5027
# 7           head & neck        grade 2     20   17585  19920  0.5027

# %% [markdown]
# ### annotations.csv

# %%
annt = df_meta.copy()
# annt.insert(loc=0, column='submitter_id', value=df_meta['patient_id'], allow_duplicates=True)
annt.insert(loc=0, column='submitter_id', value=range(len(df_meta)), allow_duplicates=True)
annt.insert(loc=1, column='slide', value=df_meta['image_id'], allow_duplicates=True)

# %%
annt
# Out:
#    submitter_id  slide         model  patient_id specimen_id        sample_id  \
# 0             0   7593  156681~154-R      156681       154-R              A26
# 1             1  11827  156681~154-R      156681       154-R     A26A88AJ3AW1
# 2             2  11520  156681~154-R      156681       154-R  A26A88AJ4I88_RG
# 3             3   9970  156681~154-R      156681       154-R     A26A89AJ5AW4
# 4             4  11107  156681~154-R      156681       154-R     A26A89AJ6AU1
# 5             5  16056  114551~080-T      114551       080-T         M667M226
# 6             6  16127  114551~080-T      114551       080-T      M667M226C21
# 7             7  16142  114551~080-T      114551       080-T      M667M226C29
# 8             8  16131  114551~080-T      114551       080-T      M667M227C30
# 9             9  16058  114551~080-T      114551       080-T         M667M228
#
#    image_id tumor_site_from_data_src tumor_type_from_data_src  \
# 0      7593                     Skin                 Melanoma
# 1     11827                     Skin                 Melanoma
# 2     11520                     Skin                 Melanoma
# 3      9970                     Skin                 Melanoma
# 4     11107                     Skin                 Melanoma
# 5     16056            Head and Neck    Salivary gland cancer
# 6     16127            Head and Neck    Salivary gland cancer
# 7     16142            Head and Neck    Salivary gland cancer
# 8     16131            Head and Neck    Salivary gland cancer
# 9     16058            Head and Neck    Salivary gland cancer
#
#   simplified_tumor_site simplified_tumor_type stage_or_grade  power  height  \
# 0                  skin              melanoma            NaN     20   16929
# 1                  skin              melanoma            NaN     20   27104
# 2                  skin              melanoma            NaN     20   23152
# 3                  skin              melanoma            NaN     20   15623
# 4                  skin              melanoma            NaN     20   24043
# 5           head & neck           head & neck        grade 2     20   18813
# 6           head & neck           head & neck        grade 2     20   14392
# 7           head & neck           head & neck        grade 2     20   17585
# 8           head & neck           head & neck        grade 2     20   17666
# 9           head & neck           head & neck        grade 2     20   17913
#
#    width     MPP
# 0  15935  0.5006
# 1  29879  0.5006
# 2  21911  0.5006
# 3  15935  0.5006
# 4  19919  0.5006
# 5  21912  0.5027
# 6  15936  0.5027
# 7  19920  0.5027
# 8  17928  0.5027
# 9  27888  0.5027

# %%
annt.to_csv('/Users/apartin/work/jdacs/slideflow-proj/pdx-proj/project/annotations.csv', index=False)
