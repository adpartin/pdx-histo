# %% [markdown]
# Extract metadata from WSI images using `Histolab` and `Opneslide`.

# %%
import os
from pathlib import Path
import pandas as pd
import numpy as np
from glob import glob

dirpath = Path.cwd()
print(dirpath)
# Out:
# /Users/apartin/work/jdacs/pdx-histo/nbs

# %%
from histolab.slide import Slide
# from histolab.tiler import RandomTiler, GridTiler, ScoreTiler
# from histolab.scorer import NucleiScorer

import openslide
# from openslide import OpenSlide

# %%
# Specify path
datapath = dirpath/'../data'
imgpath = datapath/'svs_images'  # path to raw WSI data
# outpath = datapath/'processed'        # path to save processed images
# os.makedirs(outpath, exist_ok=True)

# %%
# Glob images
files = sorted(imgpath.glob('*.svs'))
print(f'Total files: {len(files)}')
print(files[0].with_suffix('').name)
# Out:
# Total files: 146
# 10394

# %%
# Create instance of class Slide
# path: path where the WSI is saved
# processed_path: path where thumbnails and scaled images will be saved to
f_name = files[0]
img_inpath = str(f_name)
# img_out_path = os.path.join(str(outpath), files[0].with_suffix('').name)
img_outpath = os.path.join(str(datapath), 'processed', files[0].with_suffix('').name)
pdx_slide = Slide(path=img_inpath, processed_path=img_outpath)

print(f"Slide name:            {pdx_slide.name}")
print(f"Levels:                {pdx_slide.levels}")
print(f"Dimensions at level 0: {pdx_slide.dimensions}")
print(f"Dimensions at level 1: {pdx_slide.level_dimensions(level=1)}")
print(f"Dimensions at level 2: {pdx_slide.level_dimensions(level=2)}")
# Out:
# Slide name:            10394
# Levels:                [0, 1, 2]
# Dimensions at level 0: (21911, 24376)
# Dimensions at level 1: (5477, 6094)
# Dimensions at level 2: (1369, 1523)

# %%
# Explore the Slide class
print('Type:            ', type(pdx_slide._wsi.properties))
print('Total properties:', len(pdx_slide._wsi.properties))
print('AppMag value:    ', pdx_slide._wsi.properties['aperio.AppMag'])  # access a property
mag = int(pdx_slide._wsi.properties['aperio.AppMag'])

# print(pdx_slide._wsi.properties[openslide.PROPERTY_NAME_MPP_X], '\n')
# print(pdx_slide._wsi.properties, '\n')

print('Level count:      ', pdx_slide._wsi.level_count)  # access a property
print('Level downsamples:', pdx_slide._wsi.level_downsamples)  # access a property
print('Level dimensions: ', pdx_slide._wsi.level_dimensions)  # access a property
# Out:
# Type:             <class 'openslide._PropertyMap'>
# Total properties: 47
# AppMag value:     20
# Level count:       3
# Level downsamples: (1.0, 4.00027387255797, 16.005183005937205)
# Level dimensions:  ((21911, 24376), (5477, 6094), (1369, 1523))

# %% [markdown]
# ## Sampling and Resolution

# %%
def calc_eff_mpp(slide, level=0):
    """ effective MPP = downsample x MPP """
    mpp_eff = slide._wsi.level_downsamples[level] * float(slide._wsi.properties[openslide.PROPERTY_NAME_MPP_X])  # effective magnification
    print('Downsample:', slide._wsi.level_downsamples[level])
    print('Level:     ', level)
    print('MPP (um):  ', mpp_eff)
    return mpp_eff

# %%
mpp_eff = calc_eff_mpp(slide=pdx_slide, level=0)
mpp_eff = calc_eff_mpp(slide=pdx_slide, level=1)
mpp_eff = calc_eff_mpp(slide=pdx_slide, level=2)
# Out:
# Downsample: 1.0
# Level:      0
# MPP (um):   0.5006
# Downsample: 4.00027387255797
# Level:      1
# MPP (um):   2.00253710060252
# Downsample: 16.005183005937205
# Level:      2
# MPP (um):   8.012194612772166

# %%
tile_px = 300
level = 0

mpp_eff = calc_eff_mpp(pdx_slide, level=0)

tile_um = mpp_eff * tile_px
print('Tile (um):', tile_um)
# Out:
# Downsample: 1.0
# Level:      0
# MPP (um):   0.5006
# Tile (um): 150.18

# %% [markdown]
# ## Aggregate metadata from all raw slides

# %%
# Aggregate metadata into df from all slides

meta_list = []  # list of dicts
for f_name in files:
    # print(f_name.name)
    
    # Load slide
    img_inpath = str(f_name)
    # img_outpath = os.path.join(str(outpath), f_name.with_suffix('').name)
    img_outpath = os.path.join(str(datapath), 'processed', f_name.with_suffix('').name)
    pdx_slide = Slide(path=img_inpath, processed_path=img_outpath)

    # Create dict that contains the slide metadata (properties)
    ignore_property = ['aperio.User', 'openslide.comment', 'openslide.quickhash-1', 'tiff.ImageDescription']
    meta = {}
    for p_name in pdx_slide._wsi.properties:
        # print('{}: {}'.format( p_name, pdx_slide._wsi.properties[p_name] ))
        if p_name in ignore_property:
            continue
        meta[p_name] = pdx_slide._wsi.properties[p_name]
        
    # Append the slide meta to a list
    meta_list.append(meta)
    
# Create df    
meta_df = pd.DataFrame(meta_list)
meta_df = meta_df[[c for c in sorted(meta_df.columns)]]
cols = ['aperio.ImageID'] + [c for c in meta_df.columns if c != 'aperio.ImageID']
meta_df = meta_df[cols]
print('Shape', meta_df.shape)
# Out:
# Shape (146, 45)

# %%
# Save
meta_df.to_csv(datapath/'meta_from_wsi_images.csv', index=False)

# %%
display(meta_df.T)
# Out:
#                                                 0                    1    \
# aperio.ImageID                                10394                10545
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                03/20/15             04/02/15
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                               10394                10545
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               33.066841            27.839817
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         24476                21695
# aperio.OriginalWidth                          22352                20320
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                12:25:54             14:38:51
# aperio.Time Zone                          GMT-04:00            GMT-04:00
# aperio.Top                                20.427135            17.748903
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     24376                21595
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      21911                19919
# openslide.level[1].downsample    4.0002738725579698   4.0005791460108746
# openslide.level[1].height                      6094                 5398
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       5477                 4979
# openslide.level[2].downsample    16.005183005937205   8.0019619486168931
# openslide.level[2].height                      1523                 2699
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       1369                 2489
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
#                                                 2                    3    \
# aperio.ImageID                                10547                10803
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                04/02/15             04/20/15
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                               10547                10803
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               29.722946            27.465031
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         12044                18276
# aperio.OriginalWidth                          14224                22352
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                14:40:10             08:04:30
# aperio.Time Zone                          GMT-04:00            GMT-04:00
# aperio.Top                                15.658472            16.238457
# openslide.level-count                             2                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     11944                18176
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      13943                21911
# openslide.level[1].downsample    4.0004304160688662   4.0002738725579698
# openslide.level[1].height                      2986                 4544
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       3485                 5477
# openslide.level[2].downsample                   NaN   8.0012783053323595
# openslide.level[2].height                       NaN                 2272
# openslide.level[2].tile-height                  NaN                  240
# openslide.level[2].tile-width                   NaN                  240
# openslide.level[2].width                        NaN                 2738
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
#                                                 4                    5    \
# aperio.ImageID                                11055                11107
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                05/08/15             05/08/15
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                               11055                11107
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               30.421028            27.756697
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         17445                24143
# aperio.OriginalWidth                          18288                20320
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                16:01:55             16:37:45
# aperio.Time Zone                          GMT-04:00            GMT-04:00
# aperio.Top                                15.533434            17.463186
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     17345                24043
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      17927                19919
# openslide.level[1].downsample    4.0004500603614606    4.000550849340943
# openslide.level[1].height                      4336                 6010
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       4481                 4979
# openslide.level[2].downsample    8.0017931273062732   16.009690723194367
# openslide.level[2].height                      2168                 1502
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       2240                 1244
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
#                                                 6                    7    \
# aperio.ImageID                                11153                11411
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                05/13/15             05/20/15
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                               11153                11411
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               28.165678            27.875229
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         15326                17776
# aperio.OriginalWidth                          18288                18288
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                10:40:05             15:33:50
# aperio.Time Zone                          GMT-04:00            GMT-04:00
# aperio.Top                                16.889723            16.032717
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     15226                17676
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      17927                17927
# openslide.level[1].downsample    4.0005974897456333   4.0003347467083241
# openslide.level[1].height                      3806                 4419
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       4481                 4481
# openslide.level[2].downsample    8.0020879860746206   8.0024678870529655
# openslide.level[2].height                      1903                 2209
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       2240                 2240
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
#                                                 8                    9    ...  \
# aperio.ImageID                                11520                11524  ...
# aperio.AppMag                                    20                   20  ...
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR  ...
# aperio.Date                                05/29/15             05/29/15  ...
# aperio.DisplayColor                               0                    0  ...
# aperio.Exposure Scale                      0.000001             0.000001  ...
# aperio.Exposure Time                             32                   32  ...
# aperio.Filename                               11520                11524  ...
# aperio.Focus Offset                       -0.000500            -0.000500  ...
# aperio.ICC Profile                     ScanScope v1         ScanScope v1  ...
# aperio.Left                               28.466942            33.427441  ...
# aperio.LineAreaXOffset                     0.020373             0.020373  ...
# aperio.LineAreaYOffset                    -0.006643            -0.006643  ...
# aperio.LineCameraSkew                      0.001784             0.001784  ...
# aperio.MPP                                   0.5006               0.5006  ...
# aperio.OriginalHeight                         23252                14896  ...
# aperio.OriginalWidth                          22352                12192  ...
# aperio.Parmset                                  NaN                  NaN  ...
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967  ...
# aperio.SessonMode                               NaN                  NaN  ...
# aperio.StripeWidth                             2032                 2032  ...
# aperio.Time                                16:13:41             16:16:19  ...
# aperio.Time Zone                          GMT-04:00            GMT-04:00  ...
# aperio.Top                                21.015381            17.647476  ...
# openslide.level-count                             3                    3  ...
# openslide.level[0].downsample                     1                    1  ...
# openslide.level[0].height                     23152                14796  ...
# openslide.level[0].tile-height                  240                  240  ...
# openslide.level[0].tile-width                   240                  240  ...
# openslide.level[0].width                      21911                11951  ...
# openslide.level[1].downsample    4.0002738725579698   4.0005021760964183  ...
# openslide.level[1].height                      5788                 3699  ...
# openslide.level[1].tile-height                  240                  240  ...
# openslide.level[1].tile-width                   240                  240  ...
# openslide.level[1].width                       5477                 2987  ...
# openslide.level[2].downsample    8.0012783053323595   8.0034259390405644  ...
# openslide.level[2].height                      2894                 1849  ...
# openslide.level[2].tile-height                  240                  240  ...
# openslide.level[2].tile-width                   240                  240  ...
# openslide.level[2].width                       2738                 1493  ...
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004  ...
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004  ...
# openslide.objective-power                        20                   20  ...
# openslide.vendor                             aperio               aperio  ...
# tiff.ResolutionUnit                            inch                 inch  ...
#
#                                                 136                  137  \
# aperio.ImageID                                 9058                 9113
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                12/15/14             12/16/14
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                                9058                 9113
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               30.956787            33.261063
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         14428                18015
# aperio.OriginalWidth                          18288                18288
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                16:08:57             16:12:12
# aperio.Time Zone                          GMT-05:00            GMT-05:00
# aperio.Top                                16.021847            17.035185
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     14328                17915
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      17927                17927
# openslide.level[1].downsample    4.0003347467083241    4.000669717677507
# openslide.level[1].height                      3582                 4478
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       4481                 4481
# openslide.level[2].downsample    8.0015625000000004   8.0022324419383661
# openslide.level[2].height                      1791                 2239
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       2240                 2240
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
#                                                 138                  139  \
# aperio.ImageID                                 9236                 9237
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                12/30/14             12/30/14
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                                9236                 9237
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               31.250751            30.550777
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         18448                18458
# aperio.OriginalWidth                          24384                28448
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                11:57:56             11:58:42
# aperio.Time Zone                          GMT-05:00            GMT-05:00
# aperio.Top                                17.941166            17.494190
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     18348                18358
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      23903                27887
# openslide.level[1].downsample    4.0002510460251042   4.0004330895617457
# openslide.level[1].height                      4587                 4589
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       5975                 6971
# openslide.level[2].downsample    8.0020439640243648   8.0023120635329654
# openslide.level[2].height                      2293                 2294
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       2987                 3485
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
#                                                 140                  141  \
# aperio.ImageID                                 9453                 9458
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                01/13/15             01/13/15
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                                9453                 9458
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               28.701843            30.717291
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         17780                23415
# aperio.OriginalWidth                          20320                20320
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                12:23:53             12:27:02
# aperio.Time Zone                          GMT-05:00            GMT-05:00
# aperio.Top                                17.500711            18.147341
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     17680                23315
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      19919                19919
# openslide.level[1].downsample    4.0003012653143202   4.0005586434886506
# openslide.level[1].height                      4420                 5828
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       4979                 4979
# openslide.level[2].downsample    8.0014061872237843    8.001920943572447
# openslide.level[2].height                      2210                 2914
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       2489                 2489
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
#                                                 142                  143  \
# aperio.ImageID                                 9636                 9637
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                01/23/15             01/23/15
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                                9636                 9637
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               31.161007            32.069122
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         14427                14909
# aperio.OriginalWidth                          18288                16256
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                15:20:10             15:20:45
# aperio.Time Zone                          GMT-05:00            GMT-05:00
# aperio.Top                                15.653399            16.916813
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     14327                14809
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      17927                15935
# openslide.level[1].downsample    4.0007536241168697   4.0005116626809265
# openslide.level[1].height                      3581                 3702
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       4481                 3983
# openslide.level[2].downsample    8.0035178072625701   8.0020280348548471
# openslide.level[2].height                      1790                 1851
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       2240                 1991
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
#                                                 144                  145
# aperio.ImageID                                 9671                 9970
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                01/27/15             02/13/15
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                                9671                 9970
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               27.506523            32.811398
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         16635                15723
# aperio.OriginalWidth                          20320                16256
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                12:29:41             10:32:43
# aperio.Time Zone                          GMT-05:00            GMT-05:00
# aperio.Top                                16.360886            17.731367
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     16535                15623
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      19919                15935
# openslide.level[1].downsample    4.0006641978088764   4.0007607234716822
# openslide.level[1].height                      4133                 3905
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       4979                 3983
# openslide.level[2].downsample    8.0031002820930972   8.0035509433845746
# openslide.level[2].height                      2066                 1952
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       2489                 1991
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
# [45 rows x 146 columns]

# %% [markdown]
# ## Not all slides were scanned with the same resolution

# %%
meta_df['openslide.mpp-x'].value_counts()
# Out:
# 0.50270000000000004    104
# 0.50060000000000004     42
# Name: openslide.mpp-x, dtype: int64

# %%
meta_df['openslide.mpp-y'].value_counts()
# Out:
# 0.50270000000000004    104
# 0.50060000000000004     42
# Name: openslide.mpp-y, dtype: int64
