# %% [markdown]
# Extract metadata from WSI images using `Histolab` and `Opneslide`.

# %%
import os
from pathlib import Path
import pandas as pd
import numpy as np
from glob import glob

dirpath = Path.cwd()
print(dirpath)
# Out:
# /Users/apartin/Box/work/jdacs/pdx-histo/nbs

# %%
from histolab.slide import Slide
# from histolab.tiler import RandomTiler, GridTiler, ScoreTiler
# from histolab.scorer import NucleiScorer

import openslide
# from openslide import OpenSlide

# %%
# Specify path
datapath = dirpath/'../data'
imgpath  = datapath/'doe-globus-pdx-data'  # path to raw WSI data
metapath = datapath/'meta'
# outpath = datapath/'processed'        # path to save processed images
# os.makedirs(outpath, exist_ok=True)

# %%
# Glob images
files = sorted(imgpath.glob('*.svs'))
print(f'Total files: {len(files)}')
print(files[0].with_suffix('').name)
# Out:
# Total files: 469
# 10060

# %%
# Create instance of class Slide
# path: path where the WSI is saved
# processed_path: path where thumbnails and scaled images will be saved to
f_name = files[0]
img_inpath = str(f_name)
# img_out_path = os.path.join(str(outpath), files[0].with_suffix('').name)
img_outpath = os.path.join(str(datapath), 'processed', files[0].with_suffix('').name)
pdx_slide = Slide(path=img_inpath, processed_path=img_outpath)

print(f"Slide name:            {pdx_slide.name}")
print(f"Levels:                {pdx_slide.levels}")
print(f"Dimensions at level 0: {pdx_slide.dimensions}")
print(f"Dimensions at level 1: {pdx_slide.level_dimensions(level=1)}")
print(f"Dimensions at level 2: {pdx_slide.level_dimensions(level=2)}")
# Out:
# Slide name:            10060
# Levels:                [0, 1, 2]
# Dimensions at level 0: (15935, 15220)
# Dimensions at level 1: (3983, 3805)
# Dimensions at level 2: (1991, 1902)

# %%
# Explore the Slide class
print('Type:            ', type(pdx_slide._wsi.properties))
print('Total properties:', len(pdx_slide._wsi.properties))
print('AppMag value:    ', pdx_slide._wsi.properties['aperio.AppMag'])  # access a property
mag = int(pdx_slide._wsi.properties['aperio.AppMag'])

# print(pdx_slide._wsi.properties[openslide.PROPERTY_NAME_MPP_X], '\n')
# print(pdx_slide._wsi.properties, '\n')

print('Level count:      ', pdx_slide._wsi.level_count)  # access a property
print('Level downsamples:', pdx_slide._wsi.level_downsamples)  # access a property
print('Level dimensions: ', pdx_slide._wsi.level_dimensions)  # access a property
# Out:
# Type:             <class 'openslide._PropertyMap'>
# Total properties: 47
# AppMag value:     20
# Level count:       3
# Level downsamples: (1.0, 4.000376600552348, 8.00280943530852)
# Level dimensions:  ((15935, 15220), (3983, 3805), (1991, 1902))

# %% [markdown]
# ## Sampling and Resolution

# %%
def calc_eff_mpp(slide, level=0):
    """ effective MPP = downsample x MPP """
    mpp_eff = slide._wsi.level_downsamples[level] * float(slide._wsi.properties[openslide.PROPERTY_NAME_MPP_X])  # effective magnification
    print('Downsample:', slide._wsi.level_downsamples[level])
    print('Level:     ', level)
    print('MPP (um):  ', mpp_eff)
    return mpp_eff

# %%
for level in range(pdx_slide._wsi.level_count):
    mpp_eff = calc_eff_mpp(slide=pdx_slide, level=level)
# Out:
# Downsample: 1.0
# Level:      0
# MPP (um):   0.5006
# Downsample: 4.000376600552348
# Level:      1
# MPP (um):   2.0025885262365053
# Downsample: 8.00280943530852
# Level:      2
# MPP (um):   4.006206403315446

# %%
# Calc tile size
tile_px = 300
level = 0

mpp_eff = calc_eff_mpp(pdx_slide, level=0)

tile_um = mpp_eff * tile_px
print('Tile (um):', tile_um)
# Out:
# Downsample: 1.0
# Level:      0
# MPP (um):   0.5006
# Tile (um): 150.18

# %% [markdown]
# ## Aggregate metadata from all raw slides

# %%
# Aggregate metadata into df from all slides

meta_list = []  # list of dicts
for i, f_name in enumerate(files):
    # print(f_name.name)
    if i % 100 == 0:
        print(f'slide {i}: {f_name.name}')
    print(f'slide {i}: {f_name.name}')
    
    # Load slide
    img_inpath = str(f_name)
    img_outpath = os.path.join(str(datapath), 'processed', f_name.with_suffix('').name)
    pdx_slide = Slide(path=img_inpath, processed_path=img_outpath)

    # Create dict that contains the slide metadata (properties)
    ignore_property = ['aperio.User', 'openslide.comment', 'openslide.quickhash-1', 'tiff.ImageDescription']
    meta = {}
    for p_name in pdx_slide._wsi.properties:
        # print('{}: {}'.format( p_name, pdx_slide._wsi.properties[p_name] ))
        if p_name in ignore_property:
            continue
        meta[p_name] = pdx_slide._wsi.properties[p_name]
        
    # Append the slide meta to a list
    meta_list.append(meta)
    del pdx_slide
    
# Create df    
meta_df = pd.DataFrame(meta_list)
meta_df = meta_df[[c for c in sorted(meta_df.columns)]]
cols = ['aperio.ImageID'] + [c for c in meta_df.columns if c != 'aperio.ImageID']
meta_df = meta_df[cols]
print('Shape', meta_df.shape)
# Out:
# slide 0
# slide 0
# slide 1
# slide 2
# slide 3
# slide 4
# slide 5
# slide 6
# slide 7
# slide 8
# slide 9
# slide 10
# slide 11
# slide 12
# slide 13
# slide 14
# slide 15
# slide 16
# slide 17
# slide 18
# slide 19
# slide 20
# slide 21
# slide 22
# slide 23
# slide 24
# slide 25
# slide 26
# slide 27
# slide 28
# slide 29
# slide 30
# slide 31
# slide 32
# slide 33
# slide 34
# slide 35
# slide 36
# slide 37
# slide 38
# slide 39
# slide 40
# slide 41
# slide 42
# slide 43
# slide 44
# slide 45
# slide 46
# slide 47
# slide 48
# slide 49
# slide 50
# slide 51
# slide 52
# slide 53
# slide 54
# slide 55
# slide 56
# slide 57
# slide 58
# slide 59
# slide 60
# slide 61
# slide 62
# slide 63
# slide 64
# slide 65
# slide 66
# slide 67
# slide 68
# slide 69
# slide 70
# slide 71
# slide 72
# slide 73
# slide 74
# slide 75
# slide 76
# slide 77
# slide 78
# slide 79
# slide 80
# slide 81
# slide 82
# slide 83
# slide 84
# slide 85
# slide 86
# slide 87
# slide 88
# slide 89
# slide 90
# slide 91
# slide 92
# slide 93
# slide 94
# slide 95
# slide 96
# slide 97
# slide 98
# slide 99
# slide 100
# slide 100
# slide 101
# slide 102
# slide 103
# slide 104
# slide 105
# slide 106
# slide 107
# slide 108
# slide 109
# slide 110
# slide 111
# slide 112
# slide 113
# slide 114
# slide 115
# slide 116
# slide 117
# slide 118
# slide 119
# slide 120
# slide 121
# slide 122
# slide 123
# slide 124
# slide 125
# slide 126
# slide 127
# slide 128
# slide 129
# slide 130
# slide 131
# slide 132
# slide 133
# slide 134
# slide 135
# slide 136
# slide 137
# slide 138
# slide 139
# slide 140
# slide 141
# slide 142
# slide 143
# slide 144
# slide 145
# slide 146
# slide 147
# slide 148
# slide 149
# slide 150
# slide 151
# slide 152
# slide 153
# slide 154
# slide 155
# slide 156
# slide 157
# slide 158
# slide 159
# slide 160
# slide 161
# slide 162
# slide 163
# slide 164
# slide 165
# slide 166
# slide 167
# slide 168
# slide 169
# slide 170
# slide 171
# slide 172
# slide 173
# slide 174
# slide 175
# slide 176
# slide 177
# slide 178
# slide 179
# slide 180
# slide 181
# slide 182
# slide 183
# slide 184
# slide 185
# slide 186
# slide 187
# slide 188
# slide 189
# slide 190
# slide 191
# slide 192
# slide 193
# slide 194
# slide 195
# slide 196
# slide 197
# slide 198
# slide 199
# slide 200
# slide 200
# slide 201
# slide 202
# slide 203
# slide 204
# slide 205
# slide 206
# slide 207
# slide 208
# slide 209
# slide 210
# slide 211
# slide 212
# slide 213
# slide 214
# slide 215
# slide 216
# slide 217
# slide 218
# slide 219
# slide 220
# slide 221
# slide 222
# slide 223
# slide 224
# slide 225
# slide 226
# slide 227
# slide 228
# slide 229
# slide 230
# slide 231
# slide 232
# slide 233
# slide 234
# slide 235
# slide 236
# slide 237
# slide 238
# slide 239
# slide 240
# slide 241
# slide 242
# slide 243
# slide 244
# slide 245
# slide 246
# slide 247
# slide 248
# slide 249
# slide 250
# slide 251
# slide 252
# slide 253
# slide 254
# slide 255
# slide 256
# slide 257
# slide 258
# slide 259
# slide 260
# slide 261
# slide 262
# slide 263
# slide 264
# slide 265
# slide 266
# slide 267
# slide 268
# slide 269
# slide 270
# slide 271
# slide 272
# slide 273
# slide 274
# slide 275
# slide 276
# slide 277
# slide 278
# slide 279
# slide 280
# slide 281
# slide 282
# slide 283
# slide 284
# slide 285
# slide 286
# slide 287
# slide 288
# slide 289
# slide 290
# slide 291
# slide 292
# slide 293
# slide 294
# slide 295
# slide 296
# slide 297
# slide 298
# slide 299
# slide 300
# slide 300
# slide 301
# slide 302
# slide 303
# slide 304
# slide 305
# slide 306
# slide 307
# slide 308
# slide 309
# slide 310
# slide 311
# slide 312
# slide 313
# slide 314
# slide 315
# slide 316
# slide 317
# slide 318
# slide 319
# slide 320
# slide 321
# slide 322
# slide 323
# slide 324
# slide 325
# slide 326
# slide 327
# slide 328
# slide 329
# slide 330
# slide 331
# slide 332
# slide 333
# slide 334
# slide 335
# slide 336
# slide 337
# slide 338
# slide 339
# slide 340
# slide 341
# slide 342
# slide 343
# slide 344
# slide 345
# slide 346
# slide 347
# slide 348
# slide 349
# slide 350
# slide 351
# slide 352
# slide 353
# slide 354
# slide 355
# slide 356
# slide 357
# slide 358
# slide 359
# slide 360
# slide 361
# slide 362
# slide 363
# slide 364
# slide 365
# slide 366
# slide 367
# slide 368
# slide 369
# slide 370
# slide 371
# slide 372
# slide 373
# slide 374
# slide 375
# slide 376
# slide 377
# slide 378
# slide 379
# slide 380
# slide 381
# slide 382
# slide 383
# slide 384
# slide 385
# slide 386
# slide 387
# slide 388
# slide 389
# slide 390
# slide 391
# slide 392
# slide 393
# slide 394
# slide 395
# slide 396
# slide 397
# slide 398
# slide 399
# slide 400
# slide 400
# slide 401
# slide 402
# slide 403
# slide 404
# slide 405
# slide 406
# slide 407
# slide 408
# slide 409
# slide 410
# slide 411
# slide 412
# slide 413
# slide 414
# slide 415
# slide 416
# slide 417
# slide 418
# slide 419
# slide 420
# slide 421
# slide 422
# slide 423
# slide 424
# slide 425
# slide 426
# slide 427
# slide 428
# slide 429
# slide 430
# slide 431
# slide 432
# slide 433
# slide 434
# slide 435
# slide 436
# slide 437
# slide 438
# slide 439
# slide 440
# slide 441
# slide 442
# slide 443
# slide 444
# slide 445
# slide 446
# slide 447
# slide 448
# slide 449
# slide 450
# slide 451
# slide 452
# slide 453
# slide 454
# slide 455
# slide 456
# slide 457
# slide 458
# slide 459
# slide 460
# slide 461
# slide 462
# slide 463
# slide 464
# slide 465
# slide 466
# slide 467
# slide 468
# Shape (469, 45)

# %%
# Save
meta_df.to_csv(metapath/'meta_from_wsi_images.csv', index=False)

# %%
display(meta_df.T)
# Out:
#                                                 0                    1    \
# aperio.ImageID                                10060                10065
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                02/24/15             02/24/15
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                               10060                10065
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               31.857466            31.291298
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         15320                18656
# aperio.OriginalWidth                          16256                14224
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                11:16:23             11:22:13
# aperio.Time Zone                          GMT-05:00            GMT-05:00
# aperio.Top                                15.038063            17.777588
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     15220                18556
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      15935                13943
# openslide.level[1].downsample    4.0003766005523476   4.0004304160688662
# openslide.level[1].height                      3805                 4639
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       3983                 3485
# openslide.level[2].downsample    8.0028094353085208   8.0028716255522063
# openslide.level[2].height                      1902                 2319
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       1991                 1742
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
#                                                 2                    3    \
# aperio.ImageID                                10096                10256
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                02/26/15             03/06/15
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                               10096                10256
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               28.702518            25.128452
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         19022                16831
# aperio.OriginalWidth                          26416                28448
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                16:17:43             15:59:17
# aperio.Time Zone                          GMT-05:00            GMT-05:00
# aperio.Top                                17.705002            17.881044
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     18922                16731
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      25895                27887
# openslide.level[1].downsample    4.0004431482995386   4.0005738572199192
# openslide.level[1].height                      4730                 4182
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       6473                 6971
# openslide.level[2].downsample    8.0015044151812198   8.0017216642754665
# openslide.level[2].height                      2365                 2091
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       3236                 3485
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
#                                                 4                    5    \
# aperio.ImageID                                10261                10274
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                03/06/15             03/06/15
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                               10261                10274
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               30.510906            30.426165
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         14339                17934
# aperio.OriginalWidth                          16256                18288
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                16:02:29             16:10:38
# aperio.Time Zone                          GMT-05:00            GMT-05:00
# aperio.Top                                17.862057            17.086042
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     14239                17834
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      15935                17927
# openslide.level[1].downsample    4.0007980672564774   4.0005590625450225
# openslide.level[1].height                      3559                 4458
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       3983                 4481
# openslide.level[2].downsample    8.0037253080119672   8.0020111316733953
# openslide.level[2].height                      1779                 2229
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       1991                 2240
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
#                                                 6                    7    \
# aperio.ImageID                                10381                10394
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                03/20/15             03/20/15
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                               10381                10394
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               29.070549            33.066841
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         17528                24476
# aperio.OriginalWidth                          18288                22352
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                12:17:36             12:25:54
# aperio.Time Zone                          GMT-04:00            GMT-04:00
# aperio.Top                                17.172543            20.427135
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     17428                24376
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      17927                21911
# openslide.level[1].downsample    4.0003347467083241   4.0002738725579698
# openslide.level[1].height                      4357                 6094
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       4481                 5477
# openslide.level[2].downsample    8.0024807736455479   16.005183005937205
# openslide.level[2].height                      2178                 1523
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       2240                 1369
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
#                                                 8                    9    ...  \
# aperio.ImageID                                10398                10415  ...
# aperio.AppMag                                    20                   20  ...
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR  ...
# aperio.Date                                03/20/15             03/20/15  ...
# aperio.DisplayColor                               0                    0  ...
# aperio.Exposure Scale                      0.000001             0.000001  ...
# aperio.Exposure Time                             32                   32  ...
# aperio.Filename                               10398                10415  ...
# aperio.Focus Offset                       -0.000500            -0.000500  ...
# aperio.ICC Profile                     ScanScope v1         ScanScope v1  ...
# aperio.Left                               28.833080            32.606232  ...
# aperio.LineAreaXOffset                     0.020373             0.020373  ...
# aperio.LineAreaYOffset                    -0.006643            -0.006643  ...
# aperio.LineCameraSkew                      0.001784             0.001784  ...
# aperio.MPP                                   0.5006               0.5006  ...
# aperio.OriginalHeight                         24488                16050  ...
# aperio.OriginalWidth                          24384                16256  ...
# aperio.Parmset                                  NaN                  NaN  ...
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967  ...
# aperio.SessonMode                               NaN                  NaN  ...
# aperio.StripeWidth                             2032                 2032  ...
# aperio.Time                                12:28:41             12:39:49  ...
# aperio.Time Zone                          GMT-04:00            GMT-04:00  ...
# aperio.Top                                19.910906            17.813808  ...
# openslide.level-count                             3                    3  ...
# openslide.level[0].downsample                     1                    1  ...
# openslide.level[0].height                     24388                15950  ...
# openslide.level[0].tile-height                  240                  240  ...
# openslide.level[0].tile-width                   240                  240  ...
# openslide.level[0].width                      23903                15935  ...
# openslide.level[1].downsample    4.0002510460251042   4.0006274157015831  ...
# openslide.level[1].height                      6097                 3987  ...
# openslide.level[1].tile-height                  240                  240  ...
# openslide.level[1].tile-width                   240                  240  ...
# openslide.level[1].width                       5975                 3983  ...
# openslide.level[2].downsample    16.006335778690758   8.0032631790372264  ...
# openslide.level[2].height                      1524                 1993  ...
# openslide.level[2].tile-height                  240                  240  ...
# openslide.level[2].tile-width                   240                  240  ...
# openslide.level[2].width                       1493                 1991  ...
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004  ...
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004  ...
# openslide.objective-power                        20                   20  ...
# openslide.vendor                             aperio               aperio  ...
# tiff.ResolutionUnit                            inch                 inch  ...
#
#                                                 459                  460  \
# aperio.ImageID                                 9636                 9637
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                01/23/15             01/23/15
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                                9636                 9637
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               31.161007            32.069122
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         14427                14909
# aperio.OriginalWidth                          18288                16256
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                15:20:10             15:20:45
# aperio.Time Zone                          GMT-05:00            GMT-05:00
# aperio.Top                                15.653399            16.916813
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     14327                14809
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      17927                15935
# openslide.level[1].downsample    4.0007536241168697   4.0005116626809265
# openslide.level[1].height                      3581                 3702
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       4481                 3983
# openslide.level[2].downsample    8.0035178072625701   8.0020280348548471
# openslide.level[2].height                      1790                 1851
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       2240                 1991
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
#                                                 461                  462  \
# aperio.ImageID                                 9640                 9643
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                01/23/15             01/23/15
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                                9640                 9643
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               31.124920            29.480612
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         13768                18523
# aperio.OriginalWidth                          16256                22352
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                15:22:28             15:24:16
# aperio.Time Zone                          GMT-05:00            GMT-05:00
# aperio.Top                                17.165295            16.925943
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     13668                18423
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      15935                21911
# openslide.level[1].downsample    4.0003766005523476   4.0005996054569923
# openslide.level[1].height                      3417                 4605
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       3983                 5477
# openslide.level[2].downsample     8.002928870785043     8.00279872236103
# openslide.level[2].height                      1708                 2302
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       1991                 2738
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
#                                                 463                  464  \
# aperio.ImageID                                 9671                 9712
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                01/27/15             01/28/15
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                                9671                 9712
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               27.506523            31.247101
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         16635                19010
# aperio.OriginalWidth                          20320                22352
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                12:29:41             11:37:17
# aperio.Time Zone                          GMT-05:00            GMT-05:00
# aperio.Top                                16.360886            16.837996
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     16535                18910
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      19919                21911
# openslide.level[1].downsample    4.0006641978088764   4.0004854232243545
# openslide.level[1].height                      4133                 4727
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       4979                 5477
# openslide.level[2].downsample    8.0031002820930972    8.002547877909592
# openslide.level[2].height                      2066                 2363
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       2489                 2738
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
#                                                 465                  466  \
# aperio.ImageID                                 9892                 9894
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                02/11/15             02/11/15
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                                9892                 9894
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               32.354839            29.566977
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         14993                17553
# aperio.OriginalWidth                          16256                26416
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                08:52:56             08:54:10
# aperio.Time Zone                          GMT-05:00            GMT-05:00
# aperio.Top                                16.343784            18.192257
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     14893                17453
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      15935                25895
# openslide.level[1].downsample    4.0005109008478081   4.0003463318548924
# openslide.level[1].height                      3723                 4363
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       3983                 6473
# openslide.level[2].downsample    8.0031012743806009   8.0022278453822739
# openslide.level[2].height                      1861                 2181
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       1991                 3236
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
#                                                 467                  468
# aperio.ImageID                                 9926                 9970
# aperio.AppMag                                    20                   20
# aperio.DSR ID                       FR-S-DTP-430APR      FR-S-DTP-430APR
# aperio.Date                                02/11/15             02/13/15
# aperio.DisplayColor                               0                    0
# aperio.Exposure Scale                      0.000001             0.000001
# aperio.Exposure Time                             32                   32
# aperio.Filename                                9926                 9970
# aperio.Focus Offset                       -0.000500            -0.000500
# aperio.ICC Profile                     ScanScope v1         ScanScope v1
# aperio.Left                               32.766663            32.811398
# aperio.LineAreaXOffset                     0.020373             0.020373
# aperio.LineAreaYOffset                    -0.006643            -0.006643
# aperio.LineCameraSkew                      0.001784             0.001784
# aperio.MPP                                   0.5006               0.5006
# aperio.OriginalHeight                         21198                15723
# aperio.OriginalWidth                          18288                16256
# aperio.Parmset                                  NaN                  NaN
# aperio.ScanScope ID                    FR-W-S078967         FR-W-S078967
# aperio.SessonMode                               NaN                  NaN
# aperio.StripeWidth                             2032                 2032
# aperio.Time                                09:14:16             10:32:43
# aperio.Time Zone                          GMT-05:00            GMT-05:00
# aperio.Top                                16.628342            17.731367
# openslide.level-count                             3                    3
# openslide.level[0].downsample                     1                    1
# openslide.level[0].height                     21098                15623
# openslide.level[0].tile-height                  240                  240
# openslide.level[0].tile-width                   240                  240
# openslide.level[0].width                      17927                15935
# openslide.level[1].downsample    4.0005243561129511   4.0007607234716822
# openslide.level[1].height                      5274                 3905
# openslide.level[1].tile-height                  240                  240
# openslide.level[1].tile-width                   240                  240
# openslide.level[1].width                       4481                 3983
# openslide.level[2].downsample    8.0019417188092525   8.0035509433845746
# openslide.level[2].height                      2637                 1952
# openslide.level[2].tile-height                  240                  240
# openslide.level[2].tile-width                   240                  240
# openslide.level[2].width                       2240                 1991
# openslide.mpp-x                 0.50060000000000004  0.50060000000000004
# openslide.mpp-y                 0.50060000000000004  0.50060000000000004
# openslide.objective-power                        20                   20
# openslide.vendor                             aperio               aperio
# tiff.ResolutionUnit                            inch                 inch
#
# [45 rows x 469 columns]

# %% [markdown]
# ## Not all slides were scanned with the same resolution

# %%
meta_df['openslide.mpp-x'].value_counts()
# Out:
# 0.50270000000000004    319
# 0.50060000000000004    150
# Name: openslide.mpp-x, dtype: int64

# %%
meta_df['openslide.mpp-y'].value_counts()
# Out:
# 0.50270000000000004    319
# 0.50060000000000004    150
# Name: openslide.mpp-y, dtype: int64

# %%
meta_df['openslide.level-count'].value_counts()
# Out:
# 3    434
# 2     35
# Name: openslide.level-count, dtype: int64

# %%
meta_df['aperio.AppMag'].value_counts()
# Out:
# 20    469
# Name: aperio.AppMag, dtype: int64
